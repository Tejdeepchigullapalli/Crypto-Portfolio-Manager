# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejdeepchigullapalli/Crypto-Portfolio-Manager/blob/main/pythontask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A **class** is a blueprint for creating objects (a particular data structure), providing initial values for state (member variables or attributes) and implementations of behavior (member functions or methods).
#
# An **object** is an instance of a class. When you create an object, you are creating a specific entity based on the class's blueprint. Each object has its own set of data (attributes) and can perform actions (methods).

# %%
#create a class and objects using python
class Dog:
    # The __init__ method is a special method, called a constructor.
    # It's automatically called when you create a new object of the class.
    def __init__(self, name, breed):
        self.name = name  # Assign the name argument to the object's 'name' attribute
        self.breed = breed  # Assign the breed argument to the object's 'breed' attribute

    # This is a method (a function defined inside a class)
    def bark(self):
        return f"{self.name} says Woof!"

    def get_info(self):
        return f"Name: {self.name}, Breed: {self.breed}"

# Create objects (instances) of the Dog class
dog1 = Dog("Buddy", "Golden Retriever")
dog2 = Dog("Lucy", "Beagle")

# Access attributes and call methods of the objects
print(dog1.get_info())
print(dog1.bark())

print(dog2.get_info())
print(dog2.bark())
# Out:
# Name: Buddy, Breed: Golden Retriever
# Buddy says Woof!
# Name: Lucy, Breed: Beagle
# Lucy says Woof!

# %% [markdown]
# ### Abstraction
# Abstraction is about hiding the complex implementation details and showing only the essential features of an object. In Python, we can achieve this using `abc` (Abstract Base Classes) module.

# %%
#write some programs on oop concepts like abstraction, encapsulation ,polymorphism,inheritance
from abc import ABC, abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

    @abstractmethod
    def stop_engine(self):
        pass

    def drive(self):
        print("Vehicle is driving.")

class Car(Vehicle):
    def start_engine(self):
        print("Car engine started with a key.")

    def stop_engine(self):
        print("Car engine stopped.")

class Motorcycle(Vehicle):
    def start_engine(self):
        print("Motorcycle engine started with a kickstand.")

    def stop_engine(self):
        print("Motorcycle engine stopped.")

# Creating objects
my_car = Car()
my_motorcycle = Motorcycle()

my_car.start_engine()
my_car.drive()
my_car.stop_engine()

print("\n")

my_motorcycle.start_engine()
my_motorcycle.drive()
my_motorcycle.stop_engine()
# Out:
# Car engine started with a key.
# Vehicle is driving.
# Car engine stopped.
#
#
# Motorcycle engine started with a kickstand.
# Vehicle is driving.
# Motorcycle engine stopped.

# %% [markdown]
# ### Encapsulation
# Encapsulation is the bundling of data (attributes) and methods that operate on the data into a single unit (class). It also restricts direct access to some of an object's components, which can prevent accidental modification of data. In Python, we use naming conventions to indicate whether an attribute is private (single underscore `_name` for protected, double underscore `__name` for private/name mangling).

# %%
class BankAccount:
    def __init__(self, account_holder, initial_balance):
        self.__account_holder = account_holder  # Private attribute
        self.__balance = initial_balance      # Private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ${amount}. New balance: ${self.__balance}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self.__balance}")
        else:
            print("Invalid withdrawal amount or insufficient balance.")

    def get_balance(self):
        return self.__balance

    def get_account_holder(self):
        return self.__account_holder

# Creating an object
my_account = BankAccount("Alice Smith", 1000)

print(f"Account holder: {my_account.get_account_holder()}")
print(f"Initial balance: ${my_account.get_balance()}")

my_account.deposit(500)
my_account.withdraw(200)
my_account.withdraw(1500) # This should fail

# Trying to access private attribute directly (will raise AttributeError or show name mangling)
# print(my_account.__balance) # This would raise an AttributeError
print(f"Final balance: ${my_account.get_balance()}")
# Out:
# Account holder: Alice Smith
# Initial balance: $1000
# Deposited $500. New balance: $1500
# Withdrew $200. New balance: $1300
# Invalid withdrawal amount or insufficient balance.
# Final balance: $1300

# %% [markdown]
# ### Inheritance
# Inheritance allows a class (child/derived class) to inherit attributes and methods from another class (parent/base class). This promotes code reusability and establishes a 'is-a' relationship.

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        raise NotImplementedError("Subclass must implement abstract method")

    def eat(self):
        print(f"{self.name} is eating.")

class Dog(Animal):
    def __init__(self, name, breed):
        super().__init__(name) # Call parent class constructor
        self.breed = breed

    def speak(self):
        return f"{self.name} says Woof!"

    def fetch(self):
        print(f"{self.name} is fetching the ball.")

class Cat(Animal):
    def __init__(self, name):
        super().__init__(name)

    def speak(self):
        return f"{self.name} says Meow!"

    def sleep(self):
        print(f"{self.name} is sleeping peacefully.")

# Creating objects
doggy = Dog("Buddy", "Golden Retriever")
kitty = Cat("Whiskers")

print(f"{doggy.name} is a {doggy.breed}.")
print(doggy.speak())
doggy.eat()
doggy.fetch()

print("\n")

print(kitty.name)
print(kitty.speak())
kitty.eat()
kitty.sleep()
# Out:
# Buddy is a Golden Retriever.
# Buddy says Woof!
# Buddy is eating.
# Buddy is fetching the ball.
#
#
# Whiskers
# Whiskers says Meow!
# Whiskers is eating.
# Whiskers is sleeping peacefully.

# %% [markdown]
# ### Polymorphism
# Polymorphism means 'many forms'. In OOP, it refers to the ability of different objects to respond to the same method call in their own specific ways. This can be achieved through method overriding (as seen in inheritance) and duck typing.

# %%
class Bird:
    def fly(self):
        print("Bird is flying")

class Plane:
    def fly(self):
        print("Plane is soaring")

class Superman:
    def fly(self):
        print("Superman is flying high")

def make_it_fly(obj):
    obj.fly()

# Creating objects
bird = Bird()
plane = Plane()
superman = Superman()

# Calling the same method 'fly' on different objects
make_it_fly(bird)
make_it_fly(plane)
make_it_fly(superman)

print("\nPolymorphism with method overriding (from Inheritance example):")
animals = [Dog("Max", "Labrador"), Cat("Phoebe")]

for animal in animals:
    print(animal.speak()) # Each animal speaks in its own way
# Out:
# Bird is flying
# Plane is soaring
# Superman is flying high
#
# Polymorphism with method overriding (from Inheritance example):
# Max says Woof!
# Phoebe says Meow!
